# %%
import pandas as pd 
import numpy as np
import requests
import json
from pprint import pprint
from sqlalchemy import create_engine
import psycopg2

# %%
#Read in CSV file
top_100 = "Resources/top_100_all_time.csv"
top_100_df = pd.read_csv(top_100)
top_100_df.head()
# Out:
#   Index  Position           ISBN                                      Title  \
# 0     1         1  9780552149518                          Da Vinci Code,The
# 1     3         2  9780747532743  Harry Potter and the Philosopher's Stone#
# 2     7         3  9780747538486   Harry Potter and the Chamber of Secrets#
# 3     6         4  9780552150736                         Angels and Demons#
# 4     2         5  9780747551003  Harry Potter and the Order of the Phoenix
#
#            Author                    Imprint Publisher Group     Volume  \
# 0      Brown, Dan                Corgi Books  Transworld Grp  4,522,025
# 1  Rowling, J. K.  Bloomsbury Publishing PLC  Bloomsbury Grp  3,844,316
# 2  Rowling, J. K.  Bloomsbury Publishing PLC  Bloomsbury Grp  3,184,492
# 3      Brown, Dan                Corgi Books  Transworld Grp  3,096,850
# 4  Rowling, J. K.  Bloomsbury Publishing PLC  Bloomsbury Grp  3,043,226
#
#             Value     RRP     ASP    Binding    Publ Date  \
# 0  £22,857,837.53   £7.99   £5.05  Paperback   1 Mar 2004
# 1  £19,853,187.43   £6.99   £5.22  Paperback  26 Jun 1997
# 2  £16,224,021.98   £6.99   £5.07  Paperback   1 Apr 1999
# 3  £15,537,324.84   £7.99   £5.05  Paperback   1 Jul 2003
# 4  £33,925,431.19  £16.99  £11.15   Hardback  21 Jun 2003
#
#                        Product Class
# 0  F2.1  Crime, Thriller & Adventure
# 1           Y2.1  Children's Fiction
# 2           Y2.1  Children's Fiction
# 3  F2.1  Crime, Thriller & Adventure
# 4           Y2.1  Children's Fiction

# %%
# Pull certain columns
top_100_cols = ["Position","ISBN", "Title", "Author", "Volume", "Publ Date"]
top_100_transformed= top_100_df[top_100_cols].copy()

# %%
# Rename columns
top_100_transformed = top_100_transformed.rename(columns={"Position": "position",
                                                          "ISBN": "isbn",
                                                          "Title": "title",
                                                          "Author": "author",
                                                          "Volume": "volume",
                                                          "Publ Date": "publish_date"})

top_100_transformed
# Out:
#     position           isbn                                      title  \
# 0          1  9780552149518                          Da Vinci Code,The
# 1          2  9780747532743  Harry Potter and the Philosopher's Stone#
# 2          3  9780747538486   Harry Potter and the Chamber of Secrets#
# 3          4  9780552150736                         Angels and Demons#
# 4          5  9780747551003  Harry Potter and the Order of the Phoenix
# ..       ...            ...                                        ...
# 95        96  9780439993586   Amber Spyglass,The:His Dark Materials S.
# 96        97  9780552771108                     Can You Keep a Secret?
# 97        98  9780552997034                                 Down Under
# 98        99  9780099506928                           Spot of Bother,A
# 99       100  9781846053443                                 Dear Fatty
#
#               author     volume publish_date
# 0         Brown, Dan  4,522,025   1 Mar 2004
# 1     Rowling, J. K.  3,844,316  26 Jun 1997
# 2     Rowling, J. K.  3,184,492   1 Apr 1999
# 3         Brown, Dan  3,096,850   1 Jul 2003
# 4     Rowling, J. K.  3,043,226  21 Jun 2003
# ..               ...        ...          ...
# 95   Pullman, Philip    653,615  14 Sep 2001
# 96  Kinsella, Sophie    652,788  17 Mar 2003
# 97      Bryson, Bill    646,515   6 Aug 2001
# 98      Haddon, Mark    645,453   7 Jun 2007
# 99      French, Dawn    643,636   9 Oct 2008
#
# [100 rows x 6 columns]

# %%
# Drop duplicates 
top_100_transformed.drop_duplicates("isbn", inplace=True)

#Set index
top_100_transformed.set_index("position", inplace=True)

# %%
top_100_transformed
# Out:
#                    isbn                                      title  \
# position
# 1         9780552149518                          Da Vinci Code,The
# 2         9780747532743  Harry Potter and the Philosopher's Stone#
# 3         9780747538486   Harry Potter and the Chamber of Secrets#
# 4         9780552150736                         Angels and Demons#
# 5         9780747551003  Harry Potter and the Order of the Phoenix
# ...                 ...                                        ...
# 96        9780439993586   Amber Spyglass,The:His Dark Materials S.
# 97        9780552771108                     Can You Keep a Secret?
# 98        9780552997034                                 Down Under
# 99        9780099506928                           Spot of Bother,A
# 100       9781846053443                                 Dear Fatty
#
#                     author     volume publish_date
# position
# 1               Brown, Dan  4,522,025   1 Mar 2004
# 2           Rowling, J. K.  3,844,316  26 Jun 1997
# 3           Rowling, J. K.  3,184,492   1 Apr 1999
# 4               Brown, Dan  3,096,850   1 Jul 2003
# 5           Rowling, J. K.  3,043,226  21 Jun 2003
# ...                    ...        ...          ...
# 96         Pullman, Philip    653,615  14 Sep 2001
# 97        Kinsella, Sophie    652,788  17 Mar 2003
# 98            Bryson, Bill    646,515   6 Aug 2001
# 99            Haddon, Mark    645,453   7 Jun 2007
# 100           French, Dawn    643,636   9 Oct 2008
#
# [100 rows x 5 columns]

# %%
# Create engine
connection_string = "{pg_user}:{pg_password}@localhost:5432/top_100_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Table name list
engine.table_names()
# Out:
# []

# %%
# Dataframe to SQL
top_100_transformed.to_sql(name='top_books', con=engine, if_exists='append', index=False)
